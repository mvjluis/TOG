# %% [markdown]
# # TensorFlow: Image Data Generator

# %% [markdown]
# Generate batches of tensor image data with real-time data augmentation.
# The data will be looped over (in batches).

# %% [markdown]
# https://www.tensorflow.org/versions/r1.15/api_docs/python/tf/keras/preprocessing/image/ImageDataGenerator

# %%
from keras.preprocessing.image import ImageDataGenerator,load_img, img_to_array
import matplotlib.pyplot as plt
import numpy as np

# %%
img = load_img(r'dataset\training_set\dogs\dog.11.jpg')
print("The type of the image loaded is: ", type(img))
img = img_to_array(img)
print("The type of the image loaded after img_to_array is: ", type(img))
print("Shape of image: ", img.shape)
img_temp = img.astype(np.uint8)
print("Max Value of image: ", img_temp.max())
# Out:
# The type of the image loaded is:  <class 'PIL.JpegImagePlugin.JpegImageFile'>
# The type of the image loaded after img_to_array is:  <class 'numpy.ndarray'>
# Shape of image:  (101, 135, 3)
# Max Value of image:  255

# %%
plt.imshow(img_temp)
plt.show()

# %%
datagen = ImageDataGenerator()
img_gen = datagen.apply_transform(x=img, transform_parameters={'theta':40, 'brightness':0.8, 'zx':0.9, 'zy':0.9})

# %%
print("The type of the image transformed is: ", type(img_gen))
print("Shape of image generated: ", img_gen.shape)
print("Max Value of image: ", img_gen.max())
# Out:
# The type of the image transformed is:  <class 'numpy.ndarray'>
# Shape of image generated:  (101, 135, 3)
# Max Value of image:  204.0

# %%
plt.imshow(img_gen.astype(np.uint8))
plt.show()

# %% [markdown]
# __Parámetros__
#     - 'theta: Float. Rotation angle in degrees.
#     - `'tx'`: Float. Shift in the x direction.
#     - `'ty'`: Float. Shift in the y direction.
#     - `'shear'`: Float. Shear angle in degrees.
#     - `'zx'`: Float. Zoom in the x direction.
#     - `'zy'`: Float. Zoom in the y direction.
#     - `'flip_horizontal'`: Boolean. Horizontal flip.
#     - `'flip_vertical'`: Boolean. Vertical flip.
#     - `'channel_shift_intencity'`: Float. Channel shift intensity.
#     - `'brightness'`: Float. Brightness shift intensity.

# %%
tf_prmtrs = dict(
    theta = 90, # angulo de rotación en grados en las manecillas del reloj
    )
tf_prmtrs
# Out:
# {'theta': 90}

# %%
img_gen = datagen.apply_transform(x=img, transform_parameters=tf_prmtrs)
plt.imshow(img_gen.astype(np.uint8))
plt.show()

# %%
tf_prmtrs = dict(
    tx = -10, # positivo se mueve hacia arriba, negativo se mueve hacia abajo
    ty = -10, # positivo se mueve hacia izquierda, negativo se mueve hacia derecha
    )
img_gen = datagen.apply_transform(x=img, transform_parameters=tf_prmtrs)
plt.imshow(img_gen.astype(np.uint8))
plt.show()

# %%
tf_prmtrs = dict(
    shear = -23, # angulo de rotación en grados en las manecillas del reloj
    )
img_gen = datagen.apply_transform(x=img, transform_parameters=tf_prmtrs)
plt.imshow(img_gen.astype(np.uint8))
plt.show()

# %%
tf_prmtrs = dict(
    zx = 0.6, # Ampliación en eje X, zx<1 Amplia, zx>1 reduce
    zy = 0.7, # Ampliación en eje Y, zy<1 Amplia, zy>1 reduce
    )
img_gen = datagen.apply_transform(x=img, transform_parameters=tf_prmtrs)
plt.imshow(img_gen.astype(np.uint8))
plt.show()

# %%
tf_prmtrs = dict(
    flip_horizontal = True,
    flip_vertical = True,
    )
img_gen = datagen.apply_transform(x=img, transform_parameters=tf_prmtrs)
plt.imshow(img_gen.astype(np.uint8))
plt.show()

# %%
tf_prmtrs = dict(
    channel_shift_intencity = 0.5,
    brightness = 2
    )
img_gen = datagen.apply_transform(x=img, transform_parameters=tf_prmtrs)
plt.imshow(img_gen.astype(np.uint8))
plt.show()

# %%
train_datagen = ImageDataGenerator(
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True)
test_datagen = ImageDataGenerator(rescale=1./255)
train_generator = train_datagen.flow_from_directory(
        'data/train',
        target_size=(150, 150),
        batch_size=32,
        class_mode='binary')
validation_generator = test_datagen.flow_from_directory(
        'data/validation',
        target_size=(150, 150),
        batch_size=32,
        class_mode='binary')
model.fit_generator(
        train_generator,
        steps_per_epoch=2000,
        epochs=50,
        validation_data=validation_generator,
        validation_steps=800)

# %%
# Importing the Keras libraries and packages
from keras.models import Sequential
from keras.layers import Convolution2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from keras.layers import Dense
# Out:
# Using TensorFlow backend.
# C:\Users\mvjlu\.conda\envs\mlearning\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\mvjlu\.conda\envs\mlearning\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\mvjlu\.conda\envs\mlearning\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...
